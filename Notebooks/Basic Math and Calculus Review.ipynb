# %%
import numpy as np

# %% [markdown]
# <h3>Number Theory</h3>
# <ul>
# <li>Natural Numbers: 1, 2, 3, 4, 5, ...</li>
# <li>Whole Numbers: 0, 1, 2, 3, 5, ...</li>
# <li>Integers:.., -3, -2, -1, 0, 1, 2, 3, 4, ...</li>
# <li>Rational Numbers: 1/2, x/y, ...</li>
# <li>Irrational Numbers: Sqrt(2), sqrt(3), ...</li>
# <li>Real Numbers: Rational numbers as well as irrational numbers.</li>
# <li></li>
# </ul>

# %%
my_value = 2*((3+2)**2/5)-4
my_value
# Out:
# 6.0

# %% [markdown]
# <h4>Variable</h4>
# <p>A variable is a placeholder for unspecified number, e.g x is a variable in f(x) = x*3</p>

# %%
x = int(input("Enter a number: "))
product = x*4
product
# Out:
# Enter a number:  6
# 24

# %% [markdown]
# <h4>Functions</h4>
# <p>Expressions that define relationships between two or variables</p>
# <p>f(x) = 4*x + 6</p>

# %%
# Declaring a linear function
def f(x):
    return 2*x + 1

x_values = [2, 5, 3, 9]
for x in x_values: 
    y = f(x)
    print(y)
# Out:
# 5
# 11
# 7
# 19

# %%
from sympy import *
x = symbols('x')
f = 2*x + 1
plot(f)

# %%
y = x**2 + 4
plot(y)

# %% [markdown]
# <p>When a function is curvy and continous, it is called curvilinear.</p>

# %%
from sympy.plotting import plot3d
f = x**2 + 3*y
plot3d(f)

# %% [markdown]
# <h3>Summation</h3>

# %%
summation = sum(2*i for i in range(1, 6))
summation
# Out:
# 30

# %%
x = [1, 4, 6, 2]
n = len(x)
summation = sum(10*x[i] for i in range(0, n))
summation
# Out:
# 130

# %%
i, n = symbols('i n')
summation = Sum(2*i, (i, 1, n))
up_to_5 = summation.subs(n ,5)
up_to_5
# Out:
# Sum(2*i, (i, 1, 5))

# %%
up_to_5.doit()
# Out:
# 30

# %%
x = symbols('x')
expr = x**2 / x**5
expr
# Out:
# x**(-3)

# %% [markdown]
# <h3>Algebric Rules</h3>
# <ul>
#     <li>Product Rule</li>
#     <li>Power Rule</li>
#     <li>Transtive Rule</li>
# </ul>
#
# <p> Power Rule: An exponent of an exponent multiplies the exponent</p>

# %% [markdown]
# <h3>Logarithms</h3>

# %%
from math import log
log(8, 2)
# Out:
# 3.0

# %%
log(8)
# Out:
# 2.0794415416798357

# %%
log(8, 10)
# Out:
# 0.9030899869919434

# %% [markdown]
# <h3>Euler's Number and Natural Algorithms</h3>

# %%
#Calculate the interest on a loan of 100USD at a rate of 20% for 2years?
p = 100
r = .20
t = 2.0
n = 12
a = p*(1+(r/n))**(n*t)
a
# Out:
# 148.69146179463576

# %%
# Calculating interest continously
from math import exp
a = p*exp(r*t)
a
# Out:
# 149.18246976412703

# %% [markdown]
# <h3>Natural Logarithms<h3>

# %%
#using e as the base of an algorithm
from math import log
x =  log(10)
x
# Out:
# 2.302585092994046

# %%
y = log(exp(1))
y
# Out:
# 1.0

# %% [markdown]
# <h3>Limits</h3>

# %%
from sympy import *
x = symbols('x')
f = 1/x
result = limit(f, x, oo)
result
# Out:
# 0

# %%
n = symbols('n')
f = (1 + (1/n))**n
result = limit(f, n, oo)
result
# Out:
# E

# %%
result.evalf()
# Out:
# 2.71828182845905

# %% [markdown]
# <h3>Derivatives</h3>

# %%
def derivative_x(f, x, step_size):
    m = (f(x + step_size) - f(x)) / ((x + step_size) - x)
    return m

# %%
def my_function(x):
    return x**2

# %%
derivative_x(my_function, 2, .000001)
# Out:
# 4.000001000088901

# %%
x = symbols('x', positive=True)
f = 3*x**2 + 4*x**(-3)
dx_f = diff(f)
dx_f
# Out:
# 6*x - 12/x**4

# %%
# derivative calculator, not working
#def f(x):
#    return x**2
#
#def dx_f(x):
#    return 2**x
#
#slope_at_4 = dx_f.subs(x,4)
#slope_at_4

# %% [markdown]
# <h3>Partial Derivatives</h3>

# %%
#derivatives of functions that have multiple input variables
from sympy.plotting import plot3d
f = 2*x**3 + 3*y**3
diff(f, x)
# Out:
# 6*x**2

# %%
plot3d(diff(f, x))

# %% [markdown]
# #
